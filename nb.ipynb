# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
df = pd.read_csv("Australian Vehicle Prices.csv")
df.head()
# Out:
#            Brand    Year   Model               Car/Suv  \
# 0      Ssangyong  2022.0  Rexton  Sutherland Isuzu Ute
# 1             MG  2022.0     MG3             Hatchback
# 2            BMW  2022.0    430I                 Coupe
# 3  Mercedes-Benz  2011.0    E500                 Coupe
# 4        Renault  2022.0  Arkana                   SUV
#
#                                        Title UsedOrNew Transmission  \
# 0       2022 Ssangyong Rexton Ultimate (awd)      DEMO    Automatic
# 1  2022 MG MG3 Auto Excite (with Navigation)      USED    Automatic
# 2                      2022 BMW 430I M Sport      USED    Automatic
# 3           2011 Mercedes-Benz E500 Elegance      USED    Automatic
# 4                 2022 Renault Arkana Intens      USED    Automatic
#
#          Engine DriveType  FuelType FuelConsumption Kilometres   ColourExtInt  \
# 0  4 cyl, 2.2 L       AWD    Diesel  8.7 L / 100 km       5595  White / Black
# ...

# %%
df["UsedOrNew"].value_counts()
# Out:
# UsedOrNew
# USED    14994
# NEW      1227
# DEMO      512
# Name: count, dtype: int64

# %%
df = df[df["UsedOrNew"] == "USED"]
df
# Out:
#                Brand    Year    Model         Car/Suv  \
# 1                 MG  2022.0      MG3       Hatchback
# 2                BMW  2022.0     430I           Coupe
# 3      Mercedes-Benz  2011.0     E500           Coupe
# 4            Renault  2022.0   Arkana             SUV
# 5             Toyota  2004.0   Estima  ON FOUR WHEELS
# ...              ...     ...      ...             ...
# 16728         Nissan  2021.0  Qashqai             SUV
# 16729         Toyota  2014.0  Alphard        SYC Cars
# 16730  Mercedes-Benz  2012.0  S-Class  USED Dealer ad
# 16732  Mercedes-Benz  2016.0   GLC250             SUV
# 16733  Mercedes-Benz  2021.0     C200           Sedan
#
#                                            Title UsedOrNew Transmission  \
# 1      2022 MG MG3 Auto Excite (with Navigation)      USED    Automatic
# 2                          2022 BMW 430I M Sport      USED    Automatic
# 3               2011 Mercedes-Benz E500 Elegance      USED    Automatic
# ...

# %%
df["Transmission"].value_counts()
# Out:
# Transmission
# Automatic    12971
# Manual        1852
# -              171
# Name: count, dtype: int64

# %%
df = df[df["Transmission"]=="Automatic"]
df
# Out:
#                Brand    Year    Model         Car/Suv  \
# 1                 MG  2022.0      MG3       Hatchback
# 2                BMW  2022.0     430I           Coupe
# 3      Mercedes-Benz  2011.0     E500           Coupe
# 4            Renault  2022.0   Arkana             SUV
# 5             Toyota  2004.0   Estima  ON FOUR WHEELS
# ...              ...     ...      ...             ...
# 16728         Nissan  2021.0  Qashqai             SUV
# 16729         Toyota  2014.0  Alphard        SYC Cars
# 16730  Mercedes-Benz  2012.0  S-Class  USED Dealer ad
# 16732  Mercedes-Benz  2016.0   GLC250             SUV
# 16733  Mercedes-Benz  2021.0     C200           Sedan
#
#                                            Title UsedOrNew Transmission  \
# 1      2022 MG MG3 Auto Excite (with Navigation)      USED    Automatic
# 2                          2022 BMW 430I M Sport      USED    Automatic
# 3               2011 Mercedes-Benz E500 Elegance      USED    Automatic
# ...

# %%
df["Car/Suv"] = df["Car/Suv"].str.contains("SUV").astype(int)
df
# 0 nao suv
# 1 suv
# Out:
# /tmp/ipykernel_8904/73752396.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df["Car/Suv"] = df["Car/Suv"].str.contains("SUV").astype(int)
#                Brand    Year    Model  Car/Suv  \
# 1                 MG  2022.0      MG3        0
# 2                BMW  2022.0     430I        0
# 3      Mercedes-Benz  2011.0     E500        0
# 4            Renault  2022.0   Arkana        1
# 5             Toyota  2004.0   Estima        0
# ...              ...     ...      ...      ...
# 16728         Nissan  2021.0  Qashqai        1
# 16729         Toyota  2014.0  Alphard        0
# 16730  Mercedes-Benz  2012.0  S-Class        0
# 16732  Mercedes-Benz  2016.0   GLC250        1
# 16733  Mercedes-Benz  2021.0     C200        0
#
# ...

# %%
df["DriveType"].value_counts()
# Out:
# DriveType
# Front    5606
# AWD      2578
# 4WD      2315
# Rear     1766
# Other     706
# Name: count, dtype: int64

# %%
columns_to_delete = ['UsedOrNew', 'Transmission']
df.drop(columns=columns_to_delete, inplace=True)
# Out:
# /tmp/ipykernel_8904/2570791619.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df.drop(columns=columns_to_delete, inplace=True)

# %%
df
# Out:
#                Brand    Year    Model  Car/Suv  \
# 1                 MG  2022.0      MG3        0
# 2                BMW  2022.0     430I        0
# 3      Mercedes-Benz  2011.0     E500        0
# 4            Renault  2022.0   Arkana        1
# 5             Toyota  2004.0   Estima        0
# ...              ...     ...      ...      ...
# 16728         Nissan  2021.0  Qashqai        1
# 16729         Toyota  2014.0  Alphard        0
# 16730  Mercedes-Benz  2012.0  S-Class        0
# 16732  Mercedes-Benz  2016.0   GLC250        1
# 16733  Mercedes-Benz  2021.0     C200        0
#
#                                            Title        Engine DriveType  \
# 1      2022 MG MG3 Auto Excite (with Navigation)  4 cyl, 1.5 L     Front
# 2                          2022 BMW 430I M Sport    4 cyl, 2 L      Rear
# 3               2011 Mercedes-Benz E500 Elegance  8 cyl, 5.5 L      Rear
# 4                     2022 Renault Arkana Intens  4 cyl, 1.3 L     Front
# ...

# %%
df['FuelType'].value_counts()
# Out:
# FuelType
# Unleaded    5846
# Diesel      3634
# Premium     2583
# Hybrid       543
# -            249
# Electric      64
# Other         34
# LPG           15
# Leaded         3
# Name: count, dtype: int64

# %%
df.drop(columns=['FuelType'], inplace=True)
# Out:
# /tmp/ipykernel_8904/3272922452.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df.drop(columns=['FuelType'], inplace=True)

# %%
df
# Out:
#                Brand    Year    Model  Car/Suv  \
# 1                 MG  2022.0      MG3        0
# 2                BMW  2022.0     430I        0
# 3      Mercedes-Benz  2011.0     E500        0
# 4            Renault  2022.0   Arkana        1
# 5             Toyota  2004.0   Estima        0
# ...              ...     ...      ...      ...
# 16728         Nissan  2021.0  Qashqai        1
# 16729         Toyota  2014.0  Alphard        0
# 16730  Mercedes-Benz  2012.0  S-Class        0
# 16732  Mercedes-Benz  2016.0   GLC250        1
# 16733  Mercedes-Benz  2021.0     C200        0
#
#                                            Title        Engine DriveType  \
# 1      2022 MG MG3 Auto Excite (with Navigation)  4 cyl, 1.5 L     Front
# 2                          2022 BMW 430I M Sport    4 cyl, 2 L      Rear
# 3               2011 Mercedes-Benz E500 Elegance  8 cyl, 5.5 L      Rear
# 4                     2022 Renault Arkana Intens  4 cyl, 1.3 L     Front
# ...

# %%
df.drop(columns=['Title', 'FuelConsumption', 'ColourExtInt', 'BodyType'], inplace=True)
# Out:
# /tmp/ipykernel_8904/1602026994.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df.drop(columns=['Title', 'FuelConsumption', 'ColourExtInt', 'BodyType'], inplace=True)

# %%
df
# Out:
#                Brand    Year    Model  Car/Suv        Engine DriveType  \
# 1                 MG  2022.0      MG3        0  4 cyl, 1.5 L     Front
# 2                BMW  2022.0     430I        0    4 cyl, 2 L      Rear
# 3      Mercedes-Benz  2011.0     E500        0  8 cyl, 5.5 L      Rear
# 4            Renault  2022.0   Arkana        1  4 cyl, 1.3 L     Front
# 5             Toyota  2004.0   Estima        0             -     Other
# ...              ...     ...      ...      ...           ...       ...
# 16728         Nissan  2021.0  Qashqai        1    4 cyl, 2 L     Front
# 16729         Toyota  2014.0  Alphard        0             -     Front
# 16730  Mercedes-Benz  2012.0  S-Class        0             -      Rear
# 16732  Mercedes-Benz  2016.0   GLC250        1    4 cyl, 2 L       AWD
# 16733  Mercedes-Benz  2021.0     C200        0    4 cyl, 2 L      Rear
#
#       Kilometres             Location CylindersinEngine     Doors     Seats  \
# ...
